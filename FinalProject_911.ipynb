# %% [markdown]
# # Final Project - 911 End-To-End Data (Public Safety)

# %% [markdown]
# # Geidy Dorviny Molina                          ######### Professor: Liang Zhao

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Phase I - Extraction of the Data

# %%
#Extracting the data as a pandas dataFrame
Data_911 = pd.read_csv("Data/911/911_End-to-End_Data.csv",
                      delimiter = ",")
Data_911.head(20)
# Out:
#    Week Start Date          Agency  \
# 0       06/24/2019             EMS
# 1       06/24/2019             EMS
# 2       06/24/2019            FDNY
# 3       06/24/2019            FDNY
# 4       06/24/2019            FDNY
# 5       06/24/2019            FDNY
# 6       06/24/2019            NYPD
# 7       06/24/2019            NYPD
# 8       06/24/2019            NYPD
# 9       06/24/2019  NYPD (Non-CIP)
# 10      06/24/2019  NYPD (Non-CIP)
# 11      06/24/2019  NYPD (Non-CIP)
# 12      06/24/2019  NYPD (Non-CIP)
# 13      06/24/2019  NYPD (Non-CIP)
# 14      06/24/2019  NYPD (Non-CIP)
# 15      06/24/2019  NYPD (Non-CIP)
# 16      06/24/2019  NYPD (Non-CIP)
# 17      06/24/2019  NYPD (Non-CIP)
# 18      06/17/2019             EMS
# 19      06/17/2019             EMS
#
#                                   Final Incident Type  \
# 0                   1. Life Threating Med Emergencies
# 1             2. Non-Life Threatening Med Emergencies
# ...

# %%
Data_911.tail(20)
# Out:
#      Week Start Date          Agency  \
# 2480      11/07/2016            FDNY
# 2481      11/07/2016            FDNY
# 2482      11/07/2016            FDNY
# 2483      11/07/2016            NYPD
# 2484      11/07/2016            NYPD
# 2485      11/07/2016            NYPD
# 2486      11/07/2016  NYPD (Non-CIP)
# 2487      11/07/2016  NYPD (Non-CIP)
# 2488      11/07/2016  NYPD (Non-CIP)
# 2489      11/07/2016  NYPD (Non-CIP)
# 2490      11/07/2016  NYPD (Non-CIP)
# 2491      11/07/2016  NYPD (Non-CIP)
# 2492      11/07/2016  NYPD (Non-CIP)
# 2493      11/07/2016  NYPD (Non-CIP)
# 2494      11/07/2016  NYPD (Non-CIP)
# 2495      10/31/2016             EMS
# 2496      10/31/2016             EMS
# 2497      10/31/2016            FDNY
# 2498      10/31/2016            FDNY
# 2499      10/31/2016            FDNY
#
#                                     Final Incident Type  \
# 2480                            2. Non-Structural Fires
# ...

# %%
#Columns on Data set
print("Columns:", ", ".join(Data_911.columns))
# Out:
# Columns: Week Start Date, Agency, Final Incident Type, # of Incidents Calculated, Call to First Pickup, Call to PD Calltaker Handoff, Call to FDNY Pickup, Call to FDNY Job Creation, Call to EMS Pickup, Call to Agency Job Creation, Call to Agency Dispatch, Call to Agency Arrival, Call to First Arrival (Multi-Agency Incidents), Median Pickup, Median Calltaker Handoff, Median FDNY Pickup, Median FDNY Job Creation, Median Ems Pickup, Median Ems Job Creation, Median Dispatch, Median Travel, Median Cumulative First Arrival  (Multi-Agency Incidents), Average Travel, Average Dispatch, Average EMS Processing, Average EMS Pickup, Average Calltaker Processing, Average Pickup, Average FD Pickup, Average FD Processing

# %%
print("Shape:", Data_911.shape)
# Out:
# Shape: (2500, 30)

# %%
print("Data types:\n", Data_911.dtypes)
# Out:
# Data types:
#  Week Start Date                                               object
# Agency                                                        object
# Final Incident Type                                           object
# # of Incidents Calculated                                      int64
# Call to First Pickup                                         float64
# Call to PD Calltaker Handoff                                 float64
# Call to FDNY Pickup                                          float64
# Call to FDNY Job Creation                                    float64
# Call to EMS Pickup                                           float64
# Call to Agency Job Creation                                  float64
# Call to Agency Dispatch                                      float64
# Call to Agency Arrival                                       float64
# Call to First Arrival (Multi-Agency Incidents)               float64
# ...

# %%
#General Statistic of Numerical features
Data_911.describe()
# Out:
#        # of Incidents Calculated  Call to First Pickup  \
# count                2500.000000           2500.000000
# mean                 3480.561200              3.655520
# std                  3686.043533              1.678271
# min                     1.000000            -46.680000
# 25%                   659.250000              3.450000
# 50%                  2594.000000              3.620000
# 75%                  3852.750000              3.800000
# max                 15887.000000             37.690000
#
#        Call to PD Calltaker Handoff  Call to FDNY Pickup  \
# count                   2500.000000           201.000000
# mean                     135.236688            40.075274
# std                       49.740482             7.974544
# min                       25.740000            28.890000
# 25%                      101.425000            33.580000
# 50%                      144.335000            36.400000
# 75%                      169.092500            49.380000
# ...

# %% [markdown]
# # II - Dividing the Data by Police Department, Fire Department and Emergencies

# %%
#New York Fire Department
#FDNY = np.where(Agency == "FDNY")
#(Data_911('Agency') == "FDNY")
print(np.where(Data_911 == "Agency"))
# Out:
# (array([], dtype=int64), array([], dtype=int64))
# C:\Users\heidu\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
fire_department = Data_911[Data_911['Agency'] == "FDNY"]
fire_department
# Out:
#      Week Start Date Agency         Final Incident Type  \
# 2         06/24/2019   FDNY         1. Structural Fires
# 3         06/24/2019   FDNY     2. Non-Structural Fires
# 4         06/24/2019   FDNY      3. Medical Emergencies
# 5         06/24/2019   FDNY  4. Non-Medical Emergencies
# 20        06/17/2019   FDNY         1. Structural Fires
# 21        06/17/2019   FDNY     2. Non-Structural Fires
# 22        06/17/2019   FDNY      3. Medical Emergencies
# 23        06/17/2019   FDNY  4. Non-Medical Emergencies
# 39        06/10/2019   FDNY         1. Structural Fires
# 40        06/10/2019   FDNY     2. Non-Structural Fires
# 41        06/10/2019   FDNY      3. Medical Emergencies
# 42        06/10/2019   FDNY  4. Non-Medical Emergencies
# 58        06/03/2019   FDNY         1. Structural Fires
# 59        06/03/2019   FDNY     2. Non-Structural Fires
# 60        06/03/2019   FDNY      3. Medical Emergencies
# 61        06/03/2019   FDNY  4. Non-Medical Emergencies
# ...

# %%
#New York Police Department
police_department = Data_911[Data_911['Agency'] == "NYPD"]
police_department
# Out:
#      Week Start Date Agency Final Incident Type  # of Incidents Calculated  \
# 6         06/24/2019   NYPD         1. Critical                        988
# 7         06/24/2019   NYPD          2. Serious                       1919
# 8         06/24/2019   NYPD     3. Non-Critical                        441
# 24        06/17/2019   NYPD         1. Critical                       1247
# 25        06/17/2019   NYPD          2. Serious                       2523
# 26        06/17/2019   NYPD     3. Non-Critical                        672
# 43        06/10/2019   NYPD         1. Critical                       1184
# 44        06/10/2019   NYPD          2. Serious                       2532
# 45        06/10/2019   NYPD     3. Non-Critical                        650
# 62        06/03/2019   NYPD         1. Critical                       1157
# 63        06/03/2019   NYPD          2. Serious                       2501
# ...

# %%
#New York Emergencies
emergencies = Data_911[Data_911['Agency'] == "EMS"]
emergencies
# Out:
#      Week Start Date Agency                      Final Incident Type  \
# 0         06/24/2019    EMS        1. Life Threating Med Emergencies
# 1         06/24/2019    EMS  2. Non-Life Threatening Med Emergencies
# 18        06/17/2019    EMS        1. Life Threating Med Emergencies
# 19        06/17/2019    EMS  2. Non-Life Threatening Med Emergencies
# 37        06/10/2019    EMS        1. Life Threating Med Emergencies
# 38        06/10/2019    EMS  2. Non-Life Threatening Med Emergencies
# 56        06/03/2019    EMS        1. Life Threating Med Emergencies
# 57        06/03/2019    EMS  2. Non-Life Threatening Med Emergencies
# 75        05/27/2019    EMS        1. Life Threating Med Emergencies
# 76        05/27/2019    EMS  2. Non-Life Threatening Med Emergencies
# 94        05/20/2019    EMS        1. Life Threating Med Emergencies
# 95        05/20/2019    EMS  2. Non-Life Threatening Med Emergencies
# 113       05/13/2019    EMS        1. Life Threating Med Emergencies
# ...

# %% [markdown]
# # Histogram of Each Department

# %%
Data_911['Agency'].hist()
plt.title('Fire Department, Police Department, Emergencies',fontsize=15)
plt.xlabel("FDNY, NYPD, EMS", fontsize=15)
plt.ylabel("Frequency",fontsize=15)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
fire_department['Agency'].hist()
plt.title('Fire Department',fontsize=15)
plt.xlabel("FDNY", fontsize=15)
plt.ylabel("Frequency",fontsize=15)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
police_department['Agency'].hist()
plt.title('Police Department',fontsize=15)
plt.xlabel("PD", fontsize=15)
plt.ylabel("Frequency",fontsize=15)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
emergencies['Agency'].hist()
plt.title('Emergencies',fontsize=15)
plt.xlabel("EMS", fontsize=15)
plt.ylabel("Frequency",fontsize=15)
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
#  - The previous Histograms don't show a clear appreciation or distribution of the data
# - It's very hard to understand the diagram.
# - However, the diagrams show that the frequency of call to each of the departments is very high.
# - In the next part I will correlate the 911 Data for a clearer understanding.

# %% [markdown]
# # III - CORRELATION

# %% [markdown]
#  Important feature to correlate data for each department: Final Incident Type (column)
#
# - Clasiffication of Incident Type on each department
# - Incident Type average
# - Most Commom incident type calls
# - Correlation between Agency and Final Incident Type

# %%
#General Scatter plot with incident Type by department
plt.scatter(Data_911['Agency'], Data_911['Final Incident Type'], alpha = 0.05)
plt.xlabel('Agency',fontsize=12)
plt.ylabel('Final Incident Type',fontsize=12)
# Out:
# Text(0, 0.5, 'Final Incident Type')

# %% [markdown]
#  - Incident type for each department
# - EMS(Emergency), FDNY(Fire Department), NYPD(Police Department)

# %%
plt.scatter(fire_department['# of Incidents Calculated'], fire_department['Final Incident Type'])

# %%
#Scatter Plot Correlation of Fire Department Incident Types
plt.scatter(fire_department['Final Incident Type'], fire_department['# of Incidents Calculated'], alpha = 0.05)
plt.xlabel('Final Incident Type',fontsize=12)
plt.ylabel('# of Incidents Calculated',fontsize=12)
# Out:
# Text(0, 0.5, '# of Incidents Calculated')

# %%
import seaborn as sns

# %%
sns.factorplot("Final Incident Type", "# of Incidents Calculated", kind='box', data=emergencies)

# %% [markdown]
#  - The seaborn plot shows:
#     - A higher Volume of calls for Non-Life Treatening Emergencies
#     - Higher between 13000 to 15000
#     - While Life Treatening Emergencies shows 9700 to 10200

# %%
#Correlaation between all columns in dataset for the fire_department
fire_department.corr()
# Out:
#                                                     # of Incidents Calculated  \
# # of Incidents Calculated                                            1.000000
# Call to First Pickup                                                 0.059425
# Call to PD Calltaker Handoff                                         0.792003
# Call to FDNY Pickup                                                  0.928378
# Call to FDNY Job Creation                                            0.123379
# Call to EMS Pickup                                                   0.580913
# Call to Agency Job Creation                                          0.500062
# Call to Agency Dispatch                                              0.748321
# Call to Agency Arrival                                               0.828273
# Call to First Arrival (Multi-Agency Incidents)                       0.781119
# Median Pickup                                                       -0.073049
# ...

# %%
#Correlation:FDNY Final Incident vs # of Incident Types Calculated
plt.scatter(fire_department['Final Incident Type'], fire_department['# of Incidents Calculated'], alpha = 0.50)
plt.xlabel('Final Incident Type',fontsize=10 )
plt.ylabel('# of Incidents Calculated',fontsize=10)
# Out:
# Text(0, 0.5, '# of Incidents Calculated')

# %% [markdown]
#  - The plot shown for the Fire Departemnt
# - It shows a bigger number of incidents for Medical Emergencies and Non Medical emergencies
# - However for Structural and Non structural fire the incidents are smaller
# - between 0 to 1000 for Structural and Non Structural Fire
# - Between 2000 and 4500 for Medical and Non Medical Emergencies

# %%
police_department.corr()
# Out:
#                                                     # of Incidents Calculated  \
# # of Incidents Calculated                                            1.000000
# Call to First Pickup                                                 0.056781
# Call to PD Calltaker Handoff                                        -0.638187
# Call to FDNY Pickup                                                       NaN
# Call to FDNY Job Creation                                                 NaN
# Call to EMS Pickup                                                        NaN
# Call to Agency Job Creation                                               NaN
# Call to Agency Dispatch                                             -0.534010
# Call to Agency Arrival                                              -0.502905
# Call to First Arrival (Multi-Agency Incidents)                      -0.510824
# Median Pickup                                                             NaN
# ...

# %%
#Police Department
plt.scatter(police_department['Final Incident Type'], police_department['# of Incidents Calculated'], alpha = 0.50)
plt.xlabel('Final Incident Type',fontsize=12)
plt.ylabel('# of Incidents Calculated',fontsize=12)
# Out:
# Text(0, 0.5, '# of Incidents Calculated')

# %% [markdown]
#  - Scatter for The Police Department
# - The bigger # of Incidents calculated are for Serios Incidents between 1500 and 3000
# - Critical Incidents goes from 700 to 1200
# - Non Critical has the smaller # of incidents less than 1000

# %%
emergencies.corr()
# Out:
#                                                     # of Incidents Calculated  \
# # of Incidents Calculated                                            1.000000
# Call to First Pickup                                                 0.020141
# Call to PD Calltaker Handoff                                         0.826129
# Call to FDNY Pickup                                                       NaN
# Call to FDNY Job Creation                                                 NaN
# Call to EMS Pickup                                                   0.839869
# Call to Agency Job Creation                                         -0.192321
# Call to Agency Dispatch                                              0.771734
# Call to Agency Arrival                                               0.912685
# Call to First Arrival (Multi-Agency Incidents)                       0.920423
# Median Pickup                                                             NaN
# ...

# %%
#Emergencies
plt.scatter(emergencies['Final Incident Type'], emergencies['# of Incidents Calculated'], alpha = 0.50)
plt.xlabel('Final Incident Type',fontsize=12)
plt.ylabel('# of Incidents Calculated',fontsize=12)
# Out:
# Text(0, 0.5, '# of Incidents Calculated')

# %% [markdown]
#  - Scatter for Emergencies
# - The bigger # of incidents goes to Non-Life Threatening Medical Emergencies between 11000 and 16000
# - Life Threatening Med Emergencies has a smaller # of incidents between 8000 and 11000

# %% [markdown]
# # IV - Descriptive Statistics for each Department with Overall Data
# -  Descriptive statistics: minimum, mean, median, maximum, standard deviation

# %%
#FDNY
fire_department.describe()
# Out:
#        # of Incidents Calculated  Call to First Pickup  \
# count                 555.000000            555.000000
# mean                 1685.664865              3.546252
# std                  1492.258790              2.173858
# min                    82.000000            -46.680000
# 25%                   242.000000              3.460000
# 50%                   906.000000              3.630000
# 75%                  3060.500000              3.845000
# max                  5612.000000              5.020000
#
#        Call to PD Calltaker Handoff  Call to FDNY Pickup  \
# count                    555.000000           201.000000
# mean                     125.836667            40.075274
# std                       74.990576             7.974544
# min                       25.740000            28.890000
# 25%                       74.420000            33.580000
# 50%                      114.530000            36.400000
# 75%                      184.225000            49.380000
# ...

# %%
fire_department['# of Incidents Calculated'].value_counts().sort_index()
# Out:
# 82      1
# 101     1
# 103     1
# 104     1
# 110     1
# 111     2
# 112     2
# 113     1
# 114     1
# 118     3
# 119     1
# 121     2
# 124     1
# 128     1
# 129     2
# 131     2
# 132     2
# 134     1
# 138     2
# 139     1
# 141     2
# 142     1
# 143     1
# 145     2
# 146     2
# 147     1
# 148     2
# 149     1
# 152     1
# 153     1
#        ..
# 3774    2
# 3778    1
# 3780    1
# 3804    1
# 3807    1
# 3808    1
# 3823    2
# 3826    1
# 3830    1
# 3863    1
# 3865    1
# 3872    1
# 3882    1
# 3894    1
# 3895    2
# 3911    1
# 3918    1
# 3919    1
# 3933    1
# 3938    1
# 3944    1
# 4014    1
# 4023    1
# 4030    1
# 4044    1
# 4080    1
# 4103    1
# 4279    1
# 5474    1
# 5612    1
# Name: # of Incidents Calculated, Length: 431, dtype: int64

# %%
#NYPD
police_department.describe()
# Out:
#        # of Incidents Calculated  Call to First Pickup  \
# count                 414.000000            414.000000
# mean                 1330.579710              3.588213
# std                   717.329735              0.350659
# min                   441.000000              1.490000
# 25%                   730.250000              3.440000
# 50%                  1015.500000              3.600000
# 75%                  2090.750000              3.777500
# max                  2787.000000              4.840000
#
#        Call to PD Calltaker Handoff  Call to FDNY Pickup  \
# count                    414.000000                  0.0
# mean                     132.886691                  NaN
# std                       23.445974                  NaN
# min                      108.670000                  NaN
# 25%                      114.797500                  NaN
# 50%                      118.895000                  NaN
# 75%                      162.115000                  NaN
# ...

# %%
#EMS
emergencies.describe()
# Out:
#        # of Incidents Calculated  Call to First Pickup  \
# count                 278.000000            278.000000
# mean                11957.276978              3.635791
# std                  2139.707984              0.334591
# min                  7801.000000              1.640000
# 25%                  9976.500000              3.490000
# 50%                 11292.000000              3.660000
# 75%                 13902.000000              3.840000
# max                 15887.000000              4.510000
#
#        Call to PD Calltaker Handoff  Call to FDNY Pickup  \
# count                    278.000000                  0.0
# mean                      72.666763                  NaN
# std                        9.678094                  NaN
# min                       44.540000                  NaN
# 25%                       64.142500                  NaN
# 50%                       70.200000                  NaN
# 75%                       81.152500                  NaN
# ...

# %% [markdown]
# # Average of Calls to each specific department

# %%
#Splitting data by days and years
group_byday = Data_911.groupby('Week Start Date')
print(group_byday)

# %%
# Get the list of days in the dataset
# set(ratings_df['Year'])
days = np.sort(Data_911['Week Start Date'].unique())
print(days)
# Out:
# ['01/01/2018' '01/02/2017' '01/07/2019' '01/08/2018' '01/09/2017'
#  '01/14/2019' '01/15/2018' '01/16/2017' '01/21/2019' '01/22/2018'
#  '01/23/2017' '01/28/2019' '01/29/2018' '01/30/2017' '02/04/2019'
#  '02/05/2018' '02/06/2017' '02/11/2019' '02/12/2018' '02/13/2017'
#  '02/18/2019' '02/19/2018' '02/20/2017' '02/25/2019' '02/26/2018'
#  '02/27/2017' '03/04/2019' '03/05/2018' '03/06/2017' '03/11/2019'
#  '03/12/2018' '03/13/2017' '03/18/2019' '03/19/2018' '03/20/2017'
#  '03/25/2019' '03/26/2018' '03/27/2017' '04/01/2019' '04/02/2018'
#  '04/03/2017' '04/08/2019' '04/09/2018' '04/10/2017' '04/15/2019'
#  '04/16/2018' '04/17/2017' '04/22/2019' '04/23/2018' '04/24/2017'
#  '04/29/2019' '04/30/2018' '05/01/2017' '05/06/2019' '05/07/2018'
#  '05/08/2017' '05/13/2019' '05/14/2018' '05/15/2017' '05/20/2019'
#  '05/21/2018' '05/22/2017' '05/27/2019' '05/28/2018' '05/29/2017'
#  '06/03/2019' '06/04/2018' '06/05/2017' '06/10/2019' '06/11/2018'
# ...

# %%
#Create Function years
# Use apply() to apply a function to all rows
#year["DT"] = Data_911["Week Start date"].apply(datetime)
#year.head()
#Data_911['Week Start Date'] = Data_911['DT'].dt.year
import datetime
year = datetime.datetime.date.now(Data_911).year
year["DT"] = Data_911["Week Start Date"].apply(datetime)

# %%
# days = Data_911['Week Start Date']
# final_list = list(filter(lambda x: (x=2019 , days)) 
# final_list

# %% [markdown]
# # Creating functions

# %%
#Defining the specific year from group of dates
#year = Data_911["Week Start Date"]
year = datetime.datetime.today
def yearFull(year):
    if(year >= 1/1/ 2016 and year <= 12/31/ 2016 ):
        fullyear = 2016
    if (year >= 1/1/ 2017  and year < 12/31/ 2017):
        fullyear = 2017
    if (year >= 1/1/ 2018 and year <= 12/31/ 2018):
        fullyear = 2018
    if(year >= 1/1/ 2019 and year <= 12/31/ 2019):
        fullyear = 2019
        return fullyear
yearFull(1/2/ 2016)

# %%
# Exercise: How many unique Incident classifications there are
userId = Data_911['Final Incident Type']
userId_set = set(userId)
print(len(userId_set))
# Out:
# 21

# %%
#Random days pick from different years for department NYPD (Non-CIP)
days = [ 11/14/2016, 10/29/2017, 10/30/2018, 6/10/2019]
for day in days:
    police = Data_911['Agency'] == "NYPD (Non-CIP)"
    print(day)
    print(police.apply(np.max))
   # print(Incident)
# Out:
# 0.00038973922902494333
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27       True
# 28       True
# 29       True
#         ...
# 2470     True
# 2471     True
# 2472     True
# 2473     True
# 2474     True
# 2475     True
# 2476     True
# 2477    False
# 2478    False
# 2479    False
# 2480    False
# 2481    False
# 2482    False
# 2483    False
# 2484    False
# 2485    False
# 2486     True
# 2487     True
# 2488     True
# 2489     True
# 2490     True
# 2491     True
# 2492     True
# 2493     True
# 2494     True
# 2495    False
# 2496    False
# 2497    False
# 2498    False
# 2499    False
# ...

# %% [markdown]
#  - NYPD (Non-CIP) is the department with more incidents
# - Better understanding of Incidents meaning

# %%
non_cip = Data_911[Data_911['Agency'] == "NYPD (Non-CIP)"]
print(non_cip)
# Out:
#      Week Start Date          Agency  \
# 9         06/24/2019  NYPD (Non-CIP)
# 10        06/24/2019  NYPD (Non-CIP)
# 11        06/24/2019  NYPD (Non-CIP)
# 12        06/24/2019  NYPD (Non-CIP)
# 13        06/24/2019  NYPD (Non-CIP)
# 14        06/24/2019  NYPD (Non-CIP)
# 15        06/24/2019  NYPD (Non-CIP)
# 16        06/24/2019  NYPD (Non-CIP)
# 17        06/24/2019  NYPD (Non-CIP)
# 27        06/17/2019  NYPD (Non-CIP)
# 28        06/17/2019  NYPD (Non-CIP)
# 29        06/17/2019  NYPD (Non-CIP)
# 30        06/17/2019  NYPD (Non-CIP)
# 31        06/17/2019  NYPD (Non-CIP)
# 32        06/17/2019  NYPD (Non-CIP)
# 33        06/17/2019  NYPD (Non-CIP)
# 34        06/17/2019  NYPD (Non-CIP)
# 35        06/17/2019  NYPD (Non-CIP)
# 36        06/17/2019  NYPD (Non-CIP)
# 46        06/10/2019  NYPD (Non-CIP)
# 47        06/10/2019  NYPD (Non-CIP)
# 48        06/10/2019  NYPD (Non-CIP)
# 49        06/10/2019  NYPD (Non-CIP)
# 50        06/10/2019  NYPD (Non-CIP)
# ...

# %%
non_cip['Final Incident Type']
# Out:
# 9                                                  Alarms
# 10                          Disorderly Person/Group/Noise
# 11                                                Dispute
# 12      Hazardous Materials/Suspicious Letters/Package...
# 13                             Other Crimes (In Progress)
# 14                                             Past Crime
# 15                Police Officer/Security Holding Suspect
# 16                                        Possible Crimes
# 17                                       Vehicle Accident
# 27                                                 Alarms
# 28                          Disorderly Person/Group/Noise
# 29                                                Dispute
# 30      Hazardous Materials/Suspicious Letters/Package...
# 31                             Investigate/Possible Crime
# 32                             Other Crimes (In Progress)
# 33                                             Past Crime
# ...

# %%
np.sum(non_cip['Final Incident Type'].isnull(), axis = 0)
# Out:
# 0

# %%
np.sum(non_cip['Final Incident Type'] == "Possible Crimes")
# Out:
# 138

# %%
import time
start = time.time()

index_id1 = (Data_911['Agency'] == 'NYPD')
police1 = Data_911[index_id1]

index_id2 = (Data_911['Agency'] == 'NYPD (Non-CIP)')
police2 = Data_911[index_id2]

# Show the histogram 

fig = plt.figure(figsize=(10, 5))
ax1 = fig.add_subplot(1, 2, 1)
ax1.hist(police1['Agency'])
ax1.set_title("Final Incident Type")
ax1.set_ylabel("Frequency")
ax2 = fig.add_subplot(1, 2, 2)
ax2.hist(police2['Agency'])
ax2.set_title("Final Incident Type")

end = time.time()
print("Time:", (end - start))
# Out:
# Time cost: 51.07460021972656
